# %%
# 파이썬으로 엑셀 파일 다루기

# %%
import openpyxl

# %%
excel_file = openpyxl.load_workbook('shop_in_seoul.xlsx')

# %%
excel_file.sheetnames
# Out:
# ['All', 'fastfood', 'SQL']

# %%
excel_sheet = excel_file["fastfood"]

# %%
for i in excel_sheet.rows:
    print(i[0].value, i[1].value, i[2].value)
# Out:
# BIZES_NM LNO_ADR INDS_LCLS_NM
# 가니벤또 서울특별시 서대문구 창천동 30-33 음식
# 기똥찬수제햄버거&컵밥 서울특별시 관악구 신림동 1537-14 음식
# 나인온즈 서울특별시 관악구 봉천동 1626-20 음식
# 뉴욕버거 서울특별시 강서구 방화동 886 음식
# 더체인지피씨방 서울특별시 송파구 가락동 2-9 음식
# 롯데리아 서울특별시 양천구 신정동 1190-3 음식
# 롯데리아 서울특별시 강서구 공항동 1373 음식
# 롯데리아 서울특별시 양천구 목동 917-6 음식
# 롯데리아 서울특별시 동대문구 전농동 10 음식
# 롯데리아 서울특별시 용산구 한강로3가 40-999 음식
# 롯데리아 서울특별시 강서구 마곡동 759-3 음식
# 롯데리아군자점 서울특별시 광진구 군자동 478-5 음식
# 롯데리아면목중앙점 서울특별시 중랑구 면목동 126-39 음식
# 롯데리아테니스장 서울특별시 송파구 방이동 88 음식
# 롯데리아홈플러스강서점 서울특별시 강서구 등촌동 639-11 음식
# 마르코죤스 서울특별시 중랑구 신내동 393-5 음식
# 마리올라 서울특별시 영등포구 문래동3가 94 음식
# 맘스터치 서울특별시 강서구 화곡동 980-21 음식
# 맘스터치 서울특별시 동대문구 회기동 1-5 음식
# 맘스터치 서울특별시 양천구 신정동 1190-6 음식
# 맘스터치대학동점 서울특별시 관악구 신림동 238-10 음식
# 맘스터치망원역점 서울특별시 마포구 망원동 379-3 음식
# 맘스터치왕십리뉴타운점 서울특별시 성동구 하왕십리동 700 음식
# 맘스터치왕십리뉴타운점 서울특별시 성동구 상왕십리동 297 음식
# 맘스터치중곡역점 서울특별시 광진구 중곡동 166-34 음식
# 맘스터치홍대점 서울특별시 마포구 서교동 338-18 음식
# 맥도날드 서울특별시 구로구 신도림동 692 음식
# 맥도날드 서울특별시 송파구 신천동 29 음식
# 맥도날드 서울특별시 송파구 장지동 896 음식
# 맥도날드강남삼성DT점 서울특별시 강남구 삼성동 113-7 음식
# 맥도날드서울상암DMC점 서울특별시 마포구 상암동 1602 음식
# 명량푸드 서울특별시 양천구 신월동 606-39 음식
# 모노치즈 서울특별시 구로구 신도림동 692 음식
# 모스버거 서울특별시 서초구 방배동 908-6 음식
# 미드나잇인서울 서울특별시 강남구 삼성동 159 음식
# 밀크밥버거 서울특별시 중랑구 상봉동 130-56 음식
# 버거킹 서울특별시 서초구 잠원동 70-1 음식
# 버거킹 서울특별시 금천구 가산동 60-44 음식
# 버거킹 서울특별시 중구 신당동 370-64 음식
# 버거킹거여역점 서울특별시 송파구 거여동 36-4 음식
# 버거킹교대역점 서울특별시 서초구 서초동 1715-10 음식
# 버거킹낙성대2점 서울특별시 관악구 봉천동 1658-2 음식
# 버거킹장안SK점 서울특별시 동대문구 장안동 164-2 음식
# 버거킹청담주성GS점 서울특별시 강남구 청담동 132-9 음식
# 베러댄와플 서울특별시 동작구 흑석동 100-9 음식
# 베러댄와플 서울특별시 도봉구 방학동 632-44 음식
# 베러댄와플 서울특별시 강서구 방화동 186-3 음식
# 봄 서울특별시 강동구 천호동 238-1 음식
# 봉구스밥버거석계역점 서울특별시 노원구 월계동 18 음식
# 봉구스밥버거신금호역점 서울특별시 성동구 금호동2가 326 음식
# 붐바타개롱역점 서울특별시 송파구 가락동 164-21 음식
# 비엔나핫도그 서울특별시 구로구 구로동 1280 음식
# 샌토1019 서울특별시 송파구 송파동 144-3 음식
# 샐러디 서울특별시 강남구 역삼동 707-1 음식
# 샐러디 서울특별시 강남구 압구정동 494 음식
# 서브웨이용산전자랜드점 서울특별시 용산구 한강로3가 16-9 음식
# 스마일찹쌀꽈배기 서울특별시 강서구 방화동 249-69 음식
# 써브웨이 서울특별시 서초구 서초동 1717-4 음식
# 써브웨이 서울특별시 성동구 성수동1가 656-1066 음식
# 써브웨이 서울특별시 서초구 반포동 737-3 음식
# 써브웨이발산역점 서울특별시 강서구 마곡동 795-7 음식
# 씨지브이용산아이파크몰6층매점 서울특별시 용산구 한강로3가 40-999 음식
# 아띠몽 서울특별시 금천구 독산동 178-34 음식
# 아이리시포테이토 서울특별시 송파구 잠실동 10 음식
# 아이씨지치킨앤버거 서울특별시 성북구 정릉동 408-24 음식
# 아이엠어버거 서울특별시 영등포구 여의도동 45-1 음식
# 엔와이비엔비버거엔베이글 서울특별시 용산구 한남동 744-5 음식
# 영철버거 서울특별시 성북구 안암동5가 86-132 음식
# 오델리 서울특별시 중구 태평로2가 150 음식
# 와플대학 서울특별시 강북구 미아동 207-3 음식
# 와플대학신정3캠퍼스 서울특별시 양천구 신정동 1320-2 음식
# 와플마녀 서울특별시 강남구 삼성동 46 음식
# 유니넷PC존홍대점 서울특별시 마포구 서교동 364-2 음식
# 제이스쿡샵 서울특별시 마포구 중동 77-32 음식
# 준스버거 서울특별시 강북구 수유동 461-39 음식
# 창대에프씨길버거광운대점 서울특별시 노원구 월계동 411 음식
# 챠드킹버거장안점 서울특별시 동대문구 장안동 365-6 음식
# 케이에프씨코리아 서울특별시 종로구 인의동 28-2 음식
# 퀴즈노스 서울특별시 구로구 구로동 222-8 음식
# 크라제버거 서울특별시 강남구 도곡동 467 음식
# 키친502 서울특별시 동작구 신대방동 338-17 음식
# 토니버거 서울특별시 노원구 월계동 447-1 음식
# 파머스박스수서역사점 서울특별시 강남구 수서동 214-2 음식
# 파파도나스 서울특별시 서대문구 대현동 40-4 음식
# 파파이스동교점 서울특별시 서대문구 창천동 510-4 음식
# 파파이스신림점 서울특별시 관악구 신림동 1680-56 음식
# 페이머스하와이쉬림프 서울특별시 구로구 신도림동 692 음식
# 페이머스하와이쉬림프 서울특별시 광진구 자양동 227-342 음식
# 폰버거 서울특별시 양천구 목동 917-6 음식
# 핫푸드 서울특별시 강남구 삼성동 159 음식
# 해피레몬플러스 서울특별시 강서구 방화동 886 음식
# 흑돼지에꼬치다 서울특별시 중구 소공동 1 음식
# GS 서울특별시 성북구 석관동 124-34 음식
# GS25 서울특별시 양천구 목동 30-16 음식
# IN-N-JOY 서울특별시 송파구 문정동 651 음식
# IN-N-JOY 서울특별시 송파구 문정동 644-2 음식
# KFC치킨 서울특별시 노원구 중계동 503 음식
# OKPC방 서울특별시 강동구 성내동 50-16 음식

# %%
excel_file.close()

# %%
import openpyxl

def read_excel_template(filename, sheetname):
    excel_file = openpyxl.load_workbook(filename)
    
    if sheetname == '':
        excel_sheet = excel_file.active
    else:
        excel_sheet = excel_file[sheetname]
        
    return_data = list()
    
    for i in excel_sheet.rows:
        datas1 = list()
        for j in i:
            datas1.append(j.value)
        return_data.append(datas1)
        
    excel_file.close()
    return return_data

# %%
datas1 = read_excel_template('shop_in_seoul.xlsx', '')

# %%
datas1
# Out:
# [['BIZES_NM', 'LNO_ADR', 'INDS_LCLS_NM', 'INDS_MCLS_NM', 'INDS_SCLS_NM'],
#  ['가니벤또', '서울특별시 서대문구 창천동 30-33', '음식', '패스트푸드', '패스트푸드'],
#  ['기똥찬수제햄버거&컵밥', '서울특별시 관악구 신림동 1537-14', '음식', '패스트푸드', '패스트푸드'],
#  ['나인온즈', '서울특별시 관악구 봉천동 1626-20', '음식', '패스트푸드', '패스트푸드'],
#  ['뉴욕버거', '서울특별시 강서구 방화동 886', '음식', '패스트푸드', '패스트푸드'],
#  ['더체인지피씨방', '서울특별시 송파구 가락동 2-9', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 양천구 신정동 1190-3', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 강서구 공항동 1373', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 양천구 목동 917-6', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 동대문구 전농동 10', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 용산구 한강로3가 40-999', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아', '서울특별시 강서구 마곡동 759-3', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아군자점', '서울특별시 광진구 군자동 478-5', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아면목중앙점', '서울특별시 중랑구 면목동 126-39', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아테니스장', '서울특별시 송파구 방이동 88', '음식', '패스트푸드', '패스트푸드'],
#  ['롯데리아홈플러스강서점', '서울특별시 강서구 등촌동 639-11', '음식', '패스트푸드', '패스트푸드'],
#  ['마르코죤스', '서울특별시 중랑구 신내동 393-5', '음식', '패스트푸드', '패스트푸드'],
#  ['마리올라', '서울특별시 영등포구 문래동3가 94', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치', '서울특별시 강서구 화곡동 980-21', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치', '서울특별시 동대문구 회기동 1-5', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치', '서울특별시 양천구 신정동 1190-6', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치대학동점', '서울특별시 관악구 신림동 238-10', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치망원역점', '서울특별시 마포구 망원동 379-3', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치왕십리뉴타운점', '서울특별시 성동구 하왕십리동 700', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치왕십리뉴타운점', '서울특별시 성동구 상왕십리동 297', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치중곡역점', '서울특별시 광진구 중곡동 166-34', '음식', '패스트푸드', '패스트푸드'],
#  ['맘스터치홍대점', '서울특별시 마포구 서교동 338-18', '음식', '패스트푸드', '패스트푸드'],
#  ['맥도날드', '서울특별시 구로구 신도림동 692', '음식', '패스트푸드', '패스트푸드'],
#  ['맥도날드', '서울특별시 송파구 신천동 29', '음식', '패스트푸드', '패스트푸드'],
#  ['맥도날드', '서울특별시 송파구 장지동 896', '음식', '패스트푸드', '패스트푸드'],
#  ['맥도날드강남삼성DT점', '서울특별시 강남구 삼성동 113-7', '음식', '패스트푸드', '패스트푸드'],
#  ['맥도날드서울상암DMC점', '서울특별시 마포구 상암동 1602', '음식', '패스트푸드', '패스트푸드'],
#  ['명량푸드', '서울특별시 양천구 신월동 606-39', '음식', '패스트푸드', '패스트푸드'],
#  ['모노치즈', '서울특별시 구로구 신도림동 692', '음식', '패스트푸드', '패스트푸드'],
#  ['모스버거', '서울특별시 서초구 방배동 908-6', '음식', '패스트푸드', '패스트푸드'],
#  ['미드나잇인서울', '서울특별시 강남구 삼성동 159', '음식', '패스트푸드', '패스트푸드'],
#  ['밀크밥버거', '서울특별시 중랑구 상봉동 130-56', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹', '서울특별시 서초구 잠원동 70-1', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹', '서울특별시 금천구 가산동 60-44', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹', '서울특별시 중구 신당동 370-64', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹거여역점', '서울특별시 송파구 거여동 36-4', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹교대역점', '서울특별시 서초구 서초동 1715-10', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹낙성대2점', '서울특별시 관악구 봉천동 1658-2', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹장안SK점', '서울특별시 동대문구 장안동 164-2', '음식', '패스트푸드', '패스트푸드'],
#  ['버거킹청담주성GS점', '서울특별시 강남구 청담동 132-9', '음식', '패스트푸드', '패스트푸드'],
#  ['베러댄와플', '서울특별시 동작구 흑석동 100-9', '음식', '패스트푸드', '패스트푸드'],
#  ['베러댄와플', '서울특별시 도봉구 방학동 632-44', '음식', '패스트푸드', '패스트푸드'],
#  ['베러댄와플', '서울특별시 강서구 방화동 186-3', '음식', '패스트푸드', '패스트푸드'],
#  ['봄', '서울특별시 강동구 천호동 238-1', '음식', '패스트푸드', '패스트푸드'],
#  ['봉구스밥버거석계역점', '서울특별시 노원구 월계동 18', '음식', '패스트푸드', '패스트푸드'],
#  ['봉구스밥버거신금호역점', '서울특별시 성동구 금호동2가 326', '음식', '패스트푸드', '패스트푸드'],
#  ['붐바타개롱역점', '서울특별시 송파구 가락동 164-21', '음식', '패스트푸드', '패스트푸드'],
#  ['비엔나핫도그', '서울특별시 구로구 구로동 1280', '음식', '패스트푸드', '패스트푸드'],
#  ['샌토1019', '서울특별시 송파구 송파동 144-3', '음식', '패스트푸드', '패스트푸드'],
#  ['샐러디', '서울특별시 강남구 역삼동 707-1', '음식', '패스트푸드', '패스트푸드'],
#  ['샐러디', '서울특별시 강남구 압구정동 494', '음식', '패스트푸드', '패스트푸드'],
#  ['서브웨이용산전자랜드점', '서울특별시 용산구 한강로3가 16-9', '음식', '패스트푸드', '패스트푸드'],
#  ['스마일찹쌀꽈배기', '서울특별시 강서구 방화동 249-69', '음식', '패스트푸드', '패스트푸드'],
#  ['써브웨이', '서울특별시 서초구 서초동 1717-4', '음식', '패스트푸드', '패스트푸드'],
#  ['써브웨이', '서울특별시 성동구 성수동1가 656-1066', '음식', '패스트푸드', '패스트푸드'],
#  ['써브웨이', '서울특별시 서초구 반포동 737-3', '음식', '패스트푸드', '패스트푸드'],
#  ['써브웨이발산역점', '서울특별시 강서구 마곡동 795-7', '음식', '패스트푸드', '패스트푸드'],
#  ['씨지브이용산아이파크몰6층매점', '서울특별시 용산구 한강로3가 40-999', '음식', '패스트푸드', '패스트푸드'],
#  ['아띠몽', '서울특별시 금천구 독산동 178-34', '음식', '패스트푸드', '패스트푸드'],
#  ['아이리시포테이토', '서울특별시 송파구 잠실동 10', '음식', '패스트푸드', '패스트푸드'],
#  ['아이씨지치킨앤버거', '서울특별시 성북구 정릉동 408-24', '음식', '패스트푸드', '패스트푸드'],
#  ['아이엠어버거', '서울특별시 영등포구 여의도동 45-1', '음식', '패스트푸드', '패스트푸드'],
#  ['엔와이비엔비버거엔베이글', '서울특별시 용산구 한남동 744-5', '음식', '패스트푸드', '패스트푸드'],
#  ['영철버거', '서울특별시 성북구 안암동5가 86-132', '음식', '패스트푸드', '패스트푸드'],
#  ['오델리', '서울특별시 중구 태평로2가 150', '음식', '패스트푸드', '패스트푸드'],
#  ['와플대학', '서울특별시 강북구 미아동 207-3', '음식', '패스트푸드', '패스트푸드'],
#  ['와플대학신정3캠퍼스', '서울특별시 양천구 신정동 1320-2', '음식', '패스트푸드', '패스트푸드'],
#  ['와플마녀', '서울특별시 강남구 삼성동 46', '음식', '패스트푸드', '패스트푸드'],
#  ['유니넷PC존홍대점', '서울특별시 마포구 서교동 364-2', '음식', '패스트푸드', '패스트푸드'],
#  ['제이스쿡샵', '서울특별시 마포구 중동 77-32', '음식', '패스트푸드', '패스트푸드'],
#  ['준스버거', '서울특별시 강북구 수유동 461-39', '음식', '패스트푸드', '패스트푸드'],
#  ['창대에프씨길버거광운대점', '서울특별시 노원구 월계동 411', '음식', '패스트푸드', '패스트푸드'],
#  ['챠드킹버거장안점', '서울특별시 동대문구 장안동 365-6', '음식', '패스트푸드', '패스트푸드'],
#  ['케이에프씨코리아', '서울특별시 종로구 인의동 28-2', '음식', '패스트푸드', '패스트푸드'],
#  ['퀴즈노스', '서울특별시 구로구 구로동 222-8', '음식', '패스트푸드', '패스트푸드'],
#  ['크라제버거', '서울특별시 강남구 도곡동 467', '음식', '패스트푸드', '패스트푸드'],
#  ['키친502', '서울특별시 동작구 신대방동 338-17', '음식', '패스트푸드', '패스트푸드'],
#  ['토니버거', '서울특별시 노원구 월계동 447-1', '음식', '패스트푸드', '패스트푸드'],
#  ['파머스박스수서역사점', '서울특별시 강남구 수서동 214-2', '음식', '패스트푸드', '패스트푸드'],
#  ['파파도나스', '서울특별시 서대문구 대현동 40-4', '음식', '패스트푸드', '패스트푸드'],
#  ['파파이스동교점', '서울특별시 서대문구 창천동 510-4', '음식', '패스트푸드', '패스트푸드'],
#  ['파파이스신림점', '서울특별시 관악구 신림동 1680-56', '음식', '패스트푸드', '패스트푸드'],
#  ['페이머스하와이쉬림프', '서울특별시 구로구 신도림동 692', '음식', '패스트푸드', '패스트푸드'],
#  ['페이머스하와이쉬림프', '서울특별시 광진구 자양동 227-342', '음식', '패스트푸드', '패스트푸드'],
#  ['폰버거', '서울특별시 양천구 목동 917-6', '음식', '패스트푸드', '패스트푸드'],
#  ['핫푸드', '서울특별시 강남구 삼성동 159', '음식', '패스트푸드', '패스트푸드'],
#  ['해피레몬플러스', '서울특별시 강서구 방화동 886', '음식', '패스트푸드', '패스트푸드'],
#  ['흑돼지에꼬치다', '서울특별시 중구 소공동 1', '음식', '패스트푸드', '패스트푸드'],
#  ['GS', '서울특별시 성북구 석관동 124-34', '음식', '패스트푸드', '패스트푸드'],
#  ['GS25', '서울특별시 양천구 목동 30-16', '음식', '패스트푸드', '패스트푸드'],
#  ['IN-N-JOY', '서울특별시 송파구 문정동 651', '음식', '패스트푸드', '패스트푸드'],
#  ['IN-N-JOY', '서울특별시 송파구 문정동 644-2', '음식', '패스트푸드', '패스트푸드'],
#  ['KFC치킨', '서울특별시 노원구 중계동 503', '음식', '패스트푸드', '패스트푸드'],
#  ['OKPC방', '서울특별시 강동구 성내동 50-16', '음식', '패스트푸드', '패스트푸드']]
